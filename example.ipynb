# %%
from ortools.linear_solver import pywraplp
from itertools import combinations

solver = pywraplp.Solver.CreateSolver('SCIP')

if not solver:
    print('Solver not created.')
    exit()

coff = [23, 21, 19, 17, 14, 13, 13, 9]
rhs = 70
a = [solver.IntVar(0, solver.infinity(), f'value of {i} coff') for i in range(8)]
arhs = solver.IntVar(0, solver.infinity(), 'arhs')

for i in range(7):
    solver.Add(a[i] - a[i + 1]>=0)

ceilings = []
roofs = []

for i in range(8,0,-1):
    combs = combinations(range(7,-1,-1), i)
    for j in combs:
        res = sum(coff[k] for k in j)
        if res <= rhs:
            ceilings.append(j)
        if res >= rhs + 1:
            roofs.append(j)


for i in ceilings:
    solver.Add(sum(a[j] for j in i) <= arhs)

for i in roofs:
    solver.Add(sum(a[j] for j in i) >= arhs + 1)

result = arhs - a[2] - a[5]
##result=sum(a[i] for i in range(8))
solver.Minimize(result)

status = solver.Solve()

if status == pywraplp.Solver.OPTIMAL:
    print('Solution:')
    print('Objective value =', solver.Objective().Value()) 
    for i in range(8):
        print(f'a[{i}] =', a[i].solution_value())
    print('arhs =', arhs.solution_value())
else:
    print('The problem does not have an optimal solution.')
# Out:
# Solution:
# Objective value = 26.0
# a[0] = 16.0
# a[1] = 14.0
# a[2] = 13.0
# a[3] = 12.0
# a[4] = 10.0
# a[5] = 9.0
# a[6] = 9.0
# a[7] = 6.0
# arhs = 48.0

# %%
cities_data = {
    0: {
        'City': 'Winchester',
        'Values': [7, 8, 10, 12, 8.5, 4, 2, 0.6, 1.5]
    },
    1: {
        'City': 'Andover',
        'Values': [6, 6, 20, 30, 9, 4.5, 2.3, 0.7, 1.6]
    },
    2: {
        'City': 'Basingstoke',
        'Values': [2, 3, 40, 40, 2, 1.5, 0.8, 0.25, 0.5]
    },
    3: {
        'City': 'Poole',
        'Values': [14, 9, 20, 25, 10, 6, 2.6, 0.86, 1.9]
    },
    4: {
        'City': 'Woking',
        'Values': [10, 9, 10, 10, 11, 5, 2.4, 1, 2]
    },
    5: {
        'City': 'Newbury',
        'Values': [24, 15, 15, 13, 25, 1.9, 8, 2.6, 4.5]
    },
    6: {
        'City': 'Portsmouth',
        'Values': [6, 7, 50, 40, 8.5, 3, 2.5, 0.9, 1.6]
    },
    7: {
        'City': 'Alresford',
        'Values': [8, 7.5, 5, 8, 9, 4, 2.1, 0.85, 2]
    },
    8: {
        'City': 'Salisbury',
        'Values': [5, 5, 10, 10, 5, 2.5, 2, 0.65, 0.9]
    },
    9: {
        'City': 'Guildford',
        'Values': [8, 10, 30, 35, 9.5, 4.5, 2.05, 0.75, 1.7]
    },
    10: {
        'City': 'Alton',
        'Values': [7, 8, 7, 8, 3, 2, 1.9, 0.70, 0.5]
    },
    11: {
        'City': 'Weybridge',
        'Values': [5, 6.5, 9, 12, 8, 4.5, 1.8, 0.63, 1.4]
    },
    12: {
        'City': 'Dorchester',
        'Values': [6, 7.5, 10, 10, 7.5, 4, 1.5, 0.45, 1.45]
    },
    13: {
        'City': 'Bridport',
        'Values': [11, 8, 8, 10, 10, 6, 2.2, 0.65, 2.2]
    },
    14: {
        'City': 'Weymouth',
        'Values': [4, 5, 10, 10, 7.5, 3.5, 1.8, 0.62, 1.6]
    },
    15: {
        'City': 'Portland',
        'Values': [3, 3.5, 3, 20, 2, 1.5, 0.9, 0.35, 0.5]
    },
    16: {
        'City': 'Chichester',
        'Values': [5, 5.5, 8, 10, 7, 3.5, 1.2, 0.45, 1.3]
    },
    17: {
        'City': 'Petersfield',
        'Values': [21, 12, 6, 6, 15, 8, 6, 0.25, 2.9]
    },
    18: {
        'City': 'Petworth',
        'Values': [6, 5.5, 2, 2, 8, 5, 1.5, 0.55, 1.55]
    },
    19: {
        'City': 'Midhurst',
        'Values': [3, 3.6, 3, 3, 2.5, 1.5, 0.8, 0.20, 0.45]
    },
    20: {
        'City': 'Reading',
        'Values': [30, 29, 120, 80, 35, 20, 7, 2.5, 8]
    },
    21: {
        'City': 'Southampton',
        'Values': [25, 16, 110, 80, 27, 12, 6.5, 3.5, 5.4]
    },
    22: {
        'City': 'Bournemouth',
        'Values': [19, 10, 90, 22, 25, 13, 5.5, 3.1, 4.5]
    },
    23: {
        'City': 'Henley',
        'Values': [7, 6, 5, 7, 8.5, 4.5, 1.2, 0.48, 2]
    },
    24: {
        'City': 'Maidenhead',
        'Values': [12, 8, 7, 10, 12, 7, 4.5, 2, 2.3]
    },
    25: {
        'City': 'Fareham',
        'Values': [4, 6, 1, 1, 7.5, 3.5, 1.1, 0.48, 1.7]
    },
    26: {
        'City': 'Romsey',
        'Values': [2, 2.5, 1, 1, 2.5, 1, 0.4, 0.1, 0.55]
    },
    27: {
        'City': 'Ringwood',
        'Values': [2, 3.5, 2, 2, 1.9, 1.2, 0.3, 0.09, 0.4]
    }
}
print('Solution:')

from ortools.linear_solver import pywraplp
from tabulate import tabulate
table=[["location"]+[f"weights{i+1}" for i in range(9)]]
for i in range(27):
    solver = pywraplp.Solver.CreateSolver('SCIP')
    x = [solver.NumVar(0, solver.infinity(), f'weights_{i}') for i in range(9)]

    for k in range(27):
        solver.Add(sum(cities_data[k]['Values'][j] * x[j] for j in range(6,9)) <= sum(cities_data[k]['Values'][j] * x[j] for j in range(6)))
        if k==i:
            solver.Add(sum(cities_data[i]['Values'][j] * x[j] for j in range(6)) == 1)
            ##solver.Add(sum(cities_data[i]['Values'][j] * x[j] for j in range(6,9)) <= 1)


    result = sum(cities_data[i]['Values'][j] * x[j] for j in range(6, 9))
    solver.Maximize(result)

 
    status = solver.Solve()

    
    if status == pywraplp.Solver.OPTIMAL:
        
        if solver.Objective().Value()<0.9999999999999999:
            print(f'{i+1}       City: {cities_data[i]["City"]}:  ', solver.Objective().Value())
            #for j in range(9):print(f'x[{j}] =', x[j].solution_value())
            #table=[["location"]+[f"weights{i} for i in range(9)"]]
            table.append([f'{i+1}']+[x[j].solution_value() for j in range(9)])
print(tabulate(table, headers="firstrow", tablefmt="grid"))
# Out:
# Solution:
# 1       City: Winchester:   0.8353963532226083
# 2       City: Andover:   0.9173789173789172
# 4       City: Poole:   0.8644668903402889
# 5       City: Woking:   0.8449997508427517
# 10       City: Guildford:   0.8024387659836931
# 12       City: Weybridge:   0.8543451652386781
# 13       City: Dorchester:   0.8665223889892258
# 14       City: Bridport:   0.9815723686629171
# 17       City: Chichester:   0.8254171263793667
# 19       City: Petworth:   0.9878360994000843
# 20       City: Midhurst:   0.8888082972530779
# 21       City: Reading:   0.9839666828100019
# +------------+------------+------------+------------+-------------+------------+------------+------------+------------+------------+
# |   location |   weights1 |   weights2 |   weights3 |    weights4 |   weights5 |   weights6 |   weights7 |   weights8 |   weights9 |
# +============+============+============+============+=============+============+============+============+============+============+
# |          1 |  0.0124265 | 0          |  0         | 0.00247027  |  0.094728  |  0.0195458 |  0.113199  | 0.00387454 |   0.404449 |
# +------------+------------+------------+------------+-------------+------------+------------+------------+------------+------------+
# |          2 |  0.115385  | 0.0512821  |  0         | 0           |  0         |  0         |  0.39886   | 0          |   0        |
# +------------+------------+------------+------------+-------------+------------+------------+------------+------------+------------+
# |          4 |  0         | 0.0188451  |  0         | 0.000633914 |  0.0814546 |  0         |  0.0651289 | 0          |   0.365859 |
# +------------+------------+------------+------------+-------------+------------+------------+------------+------------+------------+
# |          5 |  0.0150829 | 0          |  0         | 0.000781628 |  0.0617468 |  0.032428  |  0         | 0.217669   |   0.313665 |
# +------------+------------+------------+------------+-------------+------------+------------+------------+------------+------------+
# |         10 |  0.0143329 | 0          |  0         | 0.000406728 |  0.0746368 |  0.0360115 |  0.0619834 | 0          |   0.397278 |
# +------------+------------+------------+------------+-------------+------------+------------+------------+------------+------------+
# |         12 |  0.149327  | 0          |  0.0281518 | 0           |  0         |  0         |  0.379437  | 0          |   0.122399 |
# +------------+------------+------------+------------+-------------+------------+------------+------------+------------+------------+
# |         13 |  0.0139814 | 0          |  0         | 0.00314505  |  0.117955  |  0         |  0.10961   | 0          |   0.484212 |
# +------------+------------+------------+------------+-------------+------------+------------+------------+------------+------------+
# |         14 |  0         | 0.00223337 |  0         | 0.00237124  |  0.0958421 |  0         |  0.0596026 | 0          |   0.386567 |
# +------------+------------+------------+------------+-------------+------------+------------+------------+------------+------------+
# |         17 |  0.0111081 | 0.00794823 |  0         | 0.00244265  |  0.125188  |  0         |  0.0978525 | 0          |   0.544611 |
# +------------+------------+------------+------------+-------------+------------+------------+------------+------------+------------+
# |         19 |  0         | 0.155859   |  0.0580556 | 0.0133315   |  0         |  0         |  0.141042  | 0          |   0.500822 |
# +------------+------------+------------+------------+-------------+------------+------------+------------+------------+------------+
# |         20 |  0.0180558 | 0          |  0         | 0.0105713   |  0.365648  |  0         |  0.29444   | 0.0473597  |   1.43063  |
# +------------+------------+------------+------------+-------------+------------+------------+------------+------------+------------+
# |         21 |  0.0007811 | 0.00592687 |  0         | 9.03087e-05 |  0.0227847 |  0         |  0.0193836 | 0          |   0.106035 |
# +------------+------------+------------+------------+-------------+------------+------------+------------+------------+------------+

# %%
from ortools.linear_solver import pywraplp

# Create the solver
solver = pywraplp.Solver.CreateSolver('SCIP')
if not solver:
    print('Solver not created.')
    exit()

hydrophobic_positions = [2, 4, 5, 6, 11, 12, 17, 20, 21, 25, 27, 28, 30, 31, 33, 37, 44, 46]

num_positions = len(hydrophobic_positions)
x = [[solver.BoolVar(f'x_{i}_{j}') for j in range(num_positions)]for i in range(num_positions)]

for i in range(num_positions):
    for j in range(i):
        solver.Add(x[i][j] ==0)

for i in range(num_positions):
    for j in range(i + 1, num_positions):
        if hydrophobic_positions[j] == hydrophobic_positions[i] + 1:
            solver.Add(x[i][j] == 0)

for i in range(num_positions):solver.Add(sum(x[min(i, j)][max(i, j)] for j in range(num_positions) if j != i) <= 1)





solver.Maximize(solver.Sum(x[i][j] for i in range(num_positions) for j in range(i + 1, num_positions)))

status = solver.Solve()

if status == pywraplp.Solver.OPTIMAL:
    print('Solution:')
    print('Objective value =', solver.Objective().Value())
    for i in range(num_positions):
        for j in range(i + 1, num_positions):
            if x[i][j].solution_value() > 0.5:
                print(f'Bond between hydrophobic acid at position {hydrophobic_positions[i]} and {hydrophobic_positions[j]}')
else:
    print('No optimal solution found.')
# Out:
# Solution:
# Objective value = 9.0
# Bond between hydrophobic acid at position 2 and 4
# Bond between hydrophobic acid at position 5 and 17
# Bond between hydrophobic acid at position 6 and 46
# Bond between hydrophobic acid at position 11 and 25
# Bond between hydrophobic acid at position 12 and 37
# Bond between hydrophobic acid at position 20 and 44
# Bond between hydrophobic acid at position 21 and 33
# Bond between hydrophobic acid at position 27 and 30
# Bond between hydrophobic acid at position 28 and 31
